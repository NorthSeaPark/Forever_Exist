# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import matplotlib as mpl
mpl.rcParams['font.family'] = 'serif'
import warnings; warnings.simplefilter('ignore')       #忽略警告信息；

# %%
import numpy as np
import pandas as pd
import tushare as ts

# %%
data = ts.get_k_data('hs300', start = '2021-01-01', end = '2021-12-31')[['date','close']]
# Out:
# 本接口即将停止更新，请尽快使用Pro版接口：https://waditu.com/document/2

# %%
data.rename(columns = {'close':'price'}, inplace = True)
data.set_index('date',inplace=True)

# %%
data.head()
# Out:
#               price
# date
# 2021-01-04  5267.72
# 2021-01-05  5368.50
# 2021-01-06  5417.67
# 2021-01-07  5513.66
# 2021-01-08  5495.43

# %% [markdown]
# <h2>开发思路

# %%
data['returns'] = np.log(data['price'] / data['price'].shift(1))

# %%
data.head()
# Out:
#               price   returns
# date
# 2021-01-04  5267.72       NaN
# 2021-01-05  5368.50  0.018951
# 2021-01-06  5417.67  0.009117
# 2021-01-07  5513.66  0.017563
# 2021-01-08  5495.43 -0.003312

# %%
data['position'] = np.sign(data['returns'])

# %%
data.head()
# Out:
#               price   returns  position
# date
# 2021-01-04  5267.72       NaN       NaN
# 2021-01-05  5368.50  0.018951       1.0
# 2021-01-06  5417.67  0.009117       1.0
# 2021-01-07  5513.66  0.017563       1.0
# 2021-01-08  5495.43 -0.003312      -1.0

# %%
data['strategy'] = data['position'].shift(1) * data['returns']

# %%
data.head(10)
# Out:
#               price   returns  position  strategy
# date
# 2021-01-04  5267.72       NaN       NaN       NaN
# 2021-01-05  5368.50  0.018951       1.0       NaN
# 2021-01-06  5417.67  0.009117       1.0  0.009117
# 2021-01-07  5513.66  0.017563       1.0  0.017563
# 2021-01-08  5495.43 -0.003312      -1.0 -0.003312
# 2021-01-11  5441.16 -0.009925      -1.0  0.009925
# 2021-01-12  5596.35  0.028122       1.0 -0.028122
# 2021-01-13  5577.97 -0.003290      -1.0 -0.003290
# 2021-01-14  5470.46 -0.019462      -1.0  0.019462
# 2021-01-15  5458.08 -0.002266      -1.0  0.002266

# %%
data[['returns', 'strategy']].cumsum().apply(np.exp).plot(figsize=(10, 6))    
#计算出策略的最终的累计收益；
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# <h2>优化策略

# %% [markdown]
# <h2>参数优化与穷举

# %%
data['position_5'] = np.sign(data['returns'].rolling(5).mean())

# %%
data.head(20)
# Out:
#               price   returns  position  strategy  position_5
# date
# 2021-01-04  5267.72       NaN       NaN       NaN         NaN
# 2021-01-05  5368.50  0.018951       1.0       NaN         NaN
# 2021-01-06  5417.67  0.009117       1.0  0.009117         NaN
# 2021-01-07  5513.66  0.017563       1.0  0.017563         NaN
# 2021-01-08  5495.43 -0.003312      -1.0 -0.003312         NaN
# 2021-01-11  5441.16 -0.009925      -1.0  0.009925         1.0
# 2021-01-12  5596.35  0.028122       1.0 -0.028122         1.0
# 2021-01-13  5577.97 -0.003290      -1.0 -0.003290         1.0
# 2021-01-14  5470.46 -0.019462      -1.0  0.019462        -1.0
# 2021-01-15  5458.08 -0.002266      -1.0  0.002266        -1.0
# 2021-01-18  5518.52  0.011013       1.0 -0.011013         1.0
# 2021-01-19  5437.52 -0.014787      -1.0 -0.014787        -1.0
# 2021-01-20  5476.43  0.007130       1.0 -0.007130        -1.0
# 2021-01-21  5564.97  0.016038       1.0  0.016038         1.0
# 2021-01-22  5569.78  0.000864       1.0  0.000864         1.0
# 2021-01-25  5625.92  0.010029       1.0  0.010029         1.0
# 2021-01-26  5512.97 -0.020281      -1.0 -0.020281         1.0
# 2021-01-27  5528.00  0.002723       1.0 -0.002723         1.0
# 2021-01-28  5377.14 -0.027669      -1.0 -0.027669        -1.0
# 2021-01-29  5351.96 -0.004694      -1.0  0.004694        -1.0

# %%
data['strategy_5'] = data['position_5'].shift(1) * data['returns']

# %%
data[['returns', 'strategy_5']].dropna().cumsum().apply(np.exp).plot(figsize=(10, 6))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# <h2>使用离散Return计算方法

# %%
data['returns_dis'] = data['price'] / data['price'].shift(1)-1

# %%
data['returns_dis_cum'] = (data['returns_dis']+1).cumprod()
data.head()
# Out:
#               price   returns  position  strategy  position_5  strategy_5  \
# date
# 2021-01-04  5267.72       NaN       NaN       NaN         NaN         NaN
# 2021-01-05  5368.50  0.018951       1.0       NaN         NaN         NaN
# 2021-01-06  5417.67  0.009117       1.0  0.009117         NaN         NaN
# 2021-01-07  5513.66  0.017563       1.0  0.017563         NaN         NaN
# 2021-01-08  5495.43 -0.003312      -1.0 -0.003312         NaN         NaN
#
#             returns_dis  returns_dis_cum
# date
# 2021-01-04          NaN              NaN
# 2021-01-05     0.019132         1.019132
# 2021-01-06     0.009159         1.028466
# 2021-01-07     0.017718         1.046688
# 2021-01-08    -0.003306         1.043227

# %%
price_plot = ['returns_dis_cum'] #It is a list

# %%
#非常重要
for days in [10,20,30,60]:
#     data['position_%d' % days] = np.sign(data['returns'].rolling(days).mean())
    price_plot.append('sty_cumr_%dd' % days)
    data['position_%dd' % days] = np.where(data['returns'].rolling(days).mean()>0,1,-1)
    data['strategy_%dd' % days] = data['position_%dd' % days].shift(1) * data['returns']
    data['sty_cumr_%dd' % days] = (data['strategy_%dd' % days]+1).cumprod()
